# %% [markdown]
# <a href="https://colab.research.google.com/github/We-Want-it-That-Way/Plotting/blob/main/Vrushank_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Radio High Energy Pulsars collected by @Ginna Mystica, Catherine,Ashwin

# %%
import pandas as pd
import numpy as np
import math
G={'Name of pulsar':['J0205+6449','J0218+4232','J0437-4715','J0534+2200','J1105-6107','J1124-5916','J1617-5055','J1930+1852','J2124-3358','J2229+6114'],'po':[0.06571592849324,0.00232309053151224,0.005757451936712637,0.0333924123,0.0632021309179,0.13547685441,0.069356847,0.136855046957,0.00493111494309662,0.05162357393],'pdot':[1.93754256e-13,7.73955e-20,5.729215e-20,4.20972e-13,1.584462e-14,7.52566e-13,1.351e-13,7.5057e-13,2.05705e-20,7.827e-14],'D in Kpc':[3.200,3.150,0.157,2.000,2.360, 5.000, 4.743, 7.000, 0.410, 3.000],'Age':[5.37e+03,4.76e+08,1.59e+09,1.26e+03,6.32e+04,2.85e+03, 8.13e+03, 2.89e+03, 3.8e+09, 1.05e+04],'R_L':[0,466.36,13.52,2200.00,0,0,0,0, 2.86, 13.50],'B_s':[3.61e+12,4.29e+08,4.29e+08,3.79e+12,1.01e+12,1.02e+13,3.1e+12,1.03e+13,3.22e+08,2.03e+12],
'Edot':[2.7e+37,2.4e+35,1.2e+34,4.5e+38,2.5e+36,1.2e+37,1.6e+37,1.2e+37,6.8e+33,2.2e+37],
'Edot2':[2.6e+36,2.5e+34,4.8e+35,1.1e+38,4.4e+35,4.8e+35,7.1e+35,2.4e+35,2.4e+35,2.5e+36],
'B_sI':[3.61e+12,4.27e+08,2.85e+08,3.79e+12,0,0,0,0, 1.92e+08,0],
'B_Lc':[1.19e+05,3.21e+05,2.85e+04,9.55e+05,3.76e+04,3.85e+04, 8.70e+04, 3.75e+04, 2.52e+04, 1.39e+05]}
l=pd.DataFrame(G)
l.to_csv('High_energy_pulsar.csv')
l
# Out:
#   Name of pulsar        po          pdot  D in Kpc           Age      R_L  \
# 0     J0205+6449  0.065716  1.937543e-13     3.200  5.370000e+03     0.00
# 1     J0218+4232  0.002323  7.739550e-20     3.150  4.760000e+08   466.36
# 2     J0437-4715  0.005757  5.729215e-20     0.157  1.590000e+09    13.52
# 3     J0534+2200  0.033392  4.209720e-13     2.000  1.260000e+03  2200.00
# 4     J1105-6107  0.063202  1.584462e-14     2.360  6.320000e+04     0.00
# 5     J1124-5916  0.135477  7.525660e-13     5.000  2.850000e+03     0.00
# 6     J1617-5055  0.069357  1.351000e-13     4.743  8.130000e+03     0.00
# 7     J1930+1852  0.136855  7.505700e-13     7.000  2.890000e+03     0.00
# 8     J2124-3358  0.004931  2.057050e-20     0.410  3.800000e+09     2.86
# 9     J2229+6114  0.051624  7.827000e-14     3.000  1.050000e+04    13.50
#
#             B_s          Edot         Edot2          B_sI      B_Lc
# 0  3.610000e+12  2.700000e+37  2.600000e+36  3.610000e+12  119000.0
# 1  4.290000e+08  2.400000e+35  2.500000e+34  4.270000e+08  321000.0
# 2  4.290000e+08  1.200000e+34  4.800000e+35  2.850000e+08   28500.0
# 3  3.790000e+12  4.500000e+38  1.100000e+38  3.790000e+12  955000.0
# 4  1.010000e+12  2.500000e+36  4.400000e+35  0.000000e+00   37600.0
# 5  1.020000e+13  1.200000e+37  4.800000e+35  0.000000e+00   38500.0
# 6  3.100000e+12  1.600000e+37  7.100000e+35  0.000000e+00   87000.0
# 7  1.030000e+13  1.200000e+37  2.400000e+35  0.000000e+00   37500.0
# 8  3.220000e+08  6.800000e+33  2.400000e+35  1.920000e+08   25200.0
# 9  2.030000e+12  2.200000e+37  2.500000e+36  0.000000e+00  139000.0

# %% [markdown]
# Non Radio Pulsars collected by@Anjali Shivani, Ashwin

# %%
import pandas as pd
import numpy as np
import math
A={'Name of pulsar':['J0537-6910','J0633+1746','J0543+2329','J1811-1925','J1846-0258','J0628+0909','J0633+1746','J0636-4549','J1811-4930','J1812-1718'],'po':[0.0161222220245,0.2370994416923,0.245983683333,0.06466700,0.32657128834,3.763733080,0.2370994416923,1.98459736713,1.4327041968,1.20537444137],'pdot':[5.1784338e-14,1.097087e-14,1.541956e-14,4.40e-14,7.107450e-12,0.5479e-15,1.097087e-14,3.1722e-15,2.254e-15,1.9077e-14],'D in Kpc':[49.700,0.190,1.565,5.000,5.800,1.771,0.190,0.383,1.447,3.678],'R_L':[0,0,71.03,0,0,0,0,0,0,0],'Age':[4.93e+03,3.42e+05,2.53e+05,2.33e+04,728,3.59e+07,3.42e+05,9.91e+06,1.01e+07,1e+06],'B_s':[9.25e+11,1.63e+12,1.97e+12,1.71e+12,4.88e+13,8.35e+11,1.63e+12,2.54e+12,1.82e+12,4.85e+12],'Edot':[4.9e+38,3.2e+34,4.1e+34,6.4e+36,8.1e+36,1.1e+31,3.2e+34,1.6e+31,3.0e+31,4.3e+32],'Edot2':[2.0e+35,9.0e+35,1.7e+34,2.6e+35,2.4e+35,3.6e+30,9.0e+35,1.1e+32,1.4e+31,3.2e+31],'B_sI':['NaN',1.63e+12,1.97e+12,'NaN','NaN','NaN',1.63e+12,'NaN','NaN','NaN'],'B_Lc':[2.07e+06,1.15e+03,1.24e+03,5.92e+04,1.31e+04,4.09e+00,1.15e+03,3.05e+00,5.80e+00,2.60e+01]}
p=pd.DataFrame(A)
p.to_csv('Non_Radio_pulsar.csv')
p
# Out:
#   Name of pulsar        po          pdot  D in Kpc    R_L         Age  \
# 0     J0537-6910  0.016122  5.178434e-14    49.700   0.00      4930.0
# 1     J0633+1746  0.237099  1.097087e-14     0.190   0.00    342000.0
# 2     J0543+2329  0.245984  1.541956e-14     1.565  71.03    253000.0
# 3     J1811-1925  0.064667  4.400000e-14     5.000   0.00     23300.0
# 4     J1846-0258  0.326571  7.107450e-12     5.800   0.00       728.0
# 5     J0628+0909  3.763733  5.479000e-16     1.771   0.00  35900000.0
# 6     J0633+1746  0.237099  1.097087e-14     0.190   0.00    342000.0
# 7     J0636-4549  1.984597  3.172200e-15     0.383   0.00   9910000.0
# 8     J1811-4930  1.432704  2.254000e-15     1.447   0.00  10100000.0
# 9     J1812-1718  1.205374  1.907700e-14     3.678   0.00   1000000.0
#
#             B_s          Edot         Edot2      B_sI        B_Lc
# 0  9.250000e+11  4.900000e+38  2.000000e+35       NaN  2070000.00
# 1  1.630000e+12  3.200000e+34  9.000000e+35  1.63e+12     1150.00
# 2  1.970000e+12  4.100000e+34  1.700000e+34  1.97e+12     1240.00
# 3  1.710000e+12  6.400000e+36  2.600000e+35       NaN    59200.00
# 4  4.880000e+13  8.100000e+36  2.400000e+35       NaN    13100.00
# 5  8.350000e+11  1.100000e+31  3.600000e+30       NaN        4.09
# 6  1.630000e+12  3.200000e+34  9.000000e+35  1.63e+12     1150.00
# 7  2.540000e+12  1.600000e+31  1.100000e+32       NaN        3.05
# 8  1.820000e+12  3.000000e+31  1.400000e+31       NaN        5.80
# 9  4.850000e+12  4.300000e+32  3.200000e+31       NaN       26.00

# %% [markdown]
# Magnetors collected by@Ram Kumar, Aniket

# %%
import pandas as pd
import numpy as np
import math
R={'Name of pulsar':['J0100-7211','J0525-6607','J1708-4008','J1808-2024','J1809-1943','J1841-0456','J1907+0919','J2301+5852','J1745-2900','J0525-6607'],'po':[8.020392, 0.35443759451370,11.0062624,7.55592,5.540742829,11.7889784, 5.198346,6.9790709703,3.763733080,8.0470],'pdot':[1.88e-11, 7.36052e-17,1.960e-11,5.49e-10,2.8281e-12,4.092e-11,9.2e-11,4.7123e-13,1.756e-11,6.5e-11],'D in Kpc':[59.700, 1.841,3.800,13.000,3.600,9.600,'NaN',3.300,8.300,'NaN'],'R_L':[0, 66.09,0,0,0,0,0,0,0,0],'Age':[6.76e+03,7.63e+07,8.9e+03,218,3.1e+04,4.57e+03,895,2.35e+05,3.4e+03,1.96e+03],'B_s':[3.93e+14,1.63e+11,4.7e+14,2.06e+15,1.27e+14,7.03e+14,7e+14,5.8e+13,2.6e+14,7.32e+14],'Edot':[1.4e+33,6.5e+31,5.8e+32,5.0e+34,6.6e+32,9.9e+32,2.6e+34,5.5e+31,1.3e+34,4.9e+33],'Edot2':[4.0e+29,1.9e+31,4.0e+31,3.0e+32,5.1e+31,1.1e+31,'NaN',5.0e+30,1.9e+32,'NaN'],'B_sI':['NaN', 1.62e+11,'NaN',2.06e+15, 1.27e+14,'NaN','NaN', 5.80e+13,2.60e+14,'NaN'],'B_Lc':[7.14e+00,3.44e+01,3.30e+00,4.48e+01,6.98e+00,4.02e+00,4.67e+01,1.60e+00,4.57e+01,1.32e+01]}
c=pd.DataFrame(R)
c.to_csv('magnetor_pulsar.csv')
c
# Out:
#   Name of pulsar         po          pdot D in Kpc    R_L         Age  \
# 0     J0100-7211   8.020392  1.880000e-11     59.7   0.00      6760.0
# 1     J0525-6607   0.354438  7.360520e-17    1.841  66.09  76300000.0
# 2     J1708-4008  11.006262  1.960000e-11      3.8   0.00      8900.0
# 3     J1808-2024   7.555920  5.490000e-10       13   0.00       218.0
# 4     J1809-1943   5.540743  2.828100e-12      3.6   0.00     31000.0
# 5     J1841-0456  11.788978  4.092000e-11      9.6   0.00      4570.0
# 6     J1907+0919   5.198346  9.200000e-11      NaN   0.00       895.0
# 7     J2301+5852   6.979071  4.712300e-13      3.3   0.00    235000.0
# 8     J1745-2900   3.763733  1.756000e-11      8.3   0.00      3400.0
# 9     J0525-6607   8.047000  6.500000e-11      NaN   0.00      1960.0
#
#             B_s          Edot    Edot2      B_sI   B_Lc
# 0  3.930000e+14  1.400000e+33    4e+29       NaN   7.14
# 1  1.630000e+11  6.500000e+31  1.9e+31  1.62e+11  34.40
# 2  4.700000e+14  5.800000e+32    4e+31       NaN   3.30
# 3  2.060000e+15  5.000000e+34    3e+32  2.06e+15  44.80
# 4  1.270000e+14  6.600000e+32  5.1e+31  1.27e+14   6.98
# 5  7.030000e+14  9.900000e+32  1.1e+31       NaN   4.02
# 6  7.000000e+14  2.600000e+34      NaN       NaN  46.70
# 7  5.800000e+13  5.500000e+31    5e+30   5.8e+13   1.60
# 8  2.600000e+14  1.300000e+34  1.9e+32   2.6e+14  45.70
# 9  7.320000e+14  4.900000e+33      NaN       NaN  13.20

# %% [markdown]
# Main code(high pulsar + Non Radio + Magnetors)

# %%
o=pd.concat([l,p,c],ignore_index=True)
o.to_csv('Combined_data.csv')
o
# Out:
#    Name of pulsar         po          pdot D in Kpc           Age      R_L  \
# 0      J0205+6449   0.065716  1.937543e-13      3.2  5.370000e+03     0.00
# 1      J0218+4232   0.002323  7.739550e-20     3.15  4.760000e+08   466.36
# 2      J0437-4715   0.005757  5.729215e-20    0.157  1.590000e+09    13.52
# 3      J0534+2200   0.033392  4.209720e-13        2  1.260000e+03  2200.00
# 4      J1105-6107   0.063202  1.584462e-14     2.36  6.320000e+04     0.00
# 5      J1124-5916   0.135477  7.525660e-13        5  2.850000e+03     0.00
# 6      J1617-5055   0.069357  1.351000e-13    4.743  8.130000e+03     0.00
# 7      J1930+1852   0.136855  7.505700e-13        7  2.890000e+03     0.00
# 8      J2124-3358   0.004931  2.057050e-20     0.41  3.800000e+09     2.86
# 9      J2229+6114   0.051624  7.827000e-14        3  1.050000e+04    13.50
# 10     J0537-6910   0.016122  5.178434e-14     49.7  4.930000e+03     0.00
# 11     J0633+1746   0.237099  1.097087e-14     0.19  3.420000e+05     0.00
# 12     J0543+2329   0.245984  1.541956e-14    1.565  2.530000e+05    71.03
# 13     J1811-1925   0.064667  4.400000e-14        5  2.330000e+04     0.00
# 14     J1846-0258   0.326571  7.107450e-12      5.8  7.280000e+02     0.00
# 15     J0628+0909   3.763733  5.479000e-16    1.771  3.590000e+07     0.00
# 16     J0633+1746   0.237099  1.097087e-14     0.19  3.420000e+05     0.00
# 17     J0636-4549   1.984597  3.172200e-15    0.383  9.910000e+06     0.00
# 18     J1811-4930   1.432704  2.254000e-15    1.447  1.010000e+07     0.00
# 19     J1812-1718   1.205374  1.907700e-14    3.678  1.000000e+06     0.00
# 20     J0100-7211   8.020392  1.880000e-11     59.7  6.760000e+03     0.00
# 21     J0525-6607   0.354438  7.360520e-17    1.841  7.630000e+07    66.09
# 22     J1708-4008  11.006262  1.960000e-11      3.8  8.900000e+03     0.00
# 23     J1808-2024   7.555920  5.490000e-10       13  2.180000e+02     0.00
# 24     J1809-1943   5.540743  2.828100e-12      3.6  3.100000e+04     0.00
# 25     J1841-0456  11.788978  4.092000e-11      9.6  4.570000e+03     0.00
# 26     J1907+0919   5.198346  9.200000e-11      NaN  8.950000e+02     0.00
# 27     J2301+5852   6.979071  4.712300e-13      3.3  2.350000e+05     0.00
# 28     J1745-2900   3.763733  1.756000e-11      8.3  3.400000e+03     0.00
# 29     J0525-6607   8.047000  6.500000e-11      NaN  1.960000e+03     0.00
#
#              B_s          Edot    Edot2      B_sI        B_Lc
# 0   3.610000e+12  2.700000e+37  2.6e+36  3.61e+12   119000.00
# 1   4.290000e+08  2.400000e+35  2.5e+34  4.27e+08   321000.00
# 2   4.290000e+08  1.200000e+34  4.8e+35  2.85e+08    28500.00
# 3   3.790000e+12  4.500000e+38  1.1e+38  3.79e+12   955000.00
# 4   1.010000e+12  2.500000e+36  4.4e+35         0    37600.00
# 5   1.020000e+13  1.200000e+37  4.8e+35         0    38500.00
# 6   3.100000e+12  1.600000e+37  7.1e+35         0    87000.00
# 7   1.030000e+13  1.200000e+37  2.4e+35         0    37500.00
# 8   3.220000e+08  6.800000e+33  2.4e+35  1.92e+08    25200.00
# 9   2.030000e+12  2.200000e+37  2.5e+36         0   139000.00
# 10  9.250000e+11  4.900000e+38    2e+35       NaN  2070000.00
# 11  1.630000e+12  3.200000e+34    9e+35  1.63e+12     1150.00
# 12  1.970000e+12  4.100000e+34  1.7e+34  1.97e+12     1240.00
# 13  1.710000e+12  6.400000e+36  2.6e+35       NaN    59200.00
# 14  4.880000e+13  8.100000e+36  2.4e+35       NaN    13100.00
# 15  8.350000e+11  1.100000e+31  3.6e+30       NaN        4.09
# 16  1.630000e+12  3.200000e+34    9e+35  1.63e+12     1150.00
# 17  2.540000e+12  1.600000e+31  1.1e+32       NaN        3.05
# 18  1.820000e+12  3.000000e+31  1.4e+31       NaN        5.80
# 19  4.850000e+12  4.300000e+32  3.2e+31       NaN       26.00
# 20  3.930000e+14  1.400000e+33    4e+29       NaN        7.14
# 21  1.630000e+11  6.500000e+31  1.9e+31  1.62e+11       34.40
# 22  4.700000e+14  5.800000e+32    4e+31       NaN        3.30
# 23  2.060000e+15  5.000000e+34    3e+32  2.06e+15       44.80
# 24  1.270000e+14  6.600000e+32  5.1e+31  1.27e+14        6.98
# 25  7.030000e+14  9.900000e+32  1.1e+31       NaN        4.02
# 26  7.000000e+14  2.600000e+34      NaN       NaN       46.70
# 27  5.800000e+13  5.500000e+31    5e+30   5.8e+13        1.60
# 28  2.600000e+14  1.300000e+34  1.9e+32   2.6e+14       45.70
# 29  7.320000e+14  4.900000e+33      NaN       NaN       13.20

# %% [markdown]
# ## $B_{Lc} = B_{s}(\frac{\omega R}{c})^{3} = 9.2 \times (\frac{P}{s})^{\frac{-5}{2}}(\frac{\dot{P}}{10^{-15}})^{\frac{-1}{2}}Gauss$

# %%
a=m['B_Lc']
b=m['pdot']
c=m['po']
d=m['B_s']
import matplotlib.pyplot as plt
import numpy as np
import matplotlib 
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
plt.rcParams.update({'font.size': 15})
f = plt.figure()
f.set_figwidth(7)
f.set_figheight(7)
x= np.log(((c)**(-5))*(b**(-1))) # normalized by squaring both sides of B_Lc and P*Pdot relation
y = np.log(a**2)*(10**(-15/2)) # multiplied by a factor e-15/2 (check actaul equation of relation for ref)

plt.title('$B_{Lc}^{2}$ vs $P^{-5}(\dot{P})^{-1}$')
plt.xlabel('$log(P^{-5}(\dot{P})^{-1})$')
plt.ylabel('$log(B_{Lc}^{2})$')
plt.scatter(x,y)

#plots after sorting the points
plt.scatter(np.sort(x),np.sort(y))
plt.legend(['orginal','sorted'])
fig, axs = plt.subplots(2, 2, figsize=(12, 10))
axs[0, 0].scatter(np.sort(x),np.sort(y),marker='v',color='magenta')
axs[0, 1].plot(np.sort(x), np.sort(y),marker='*',color='black')
axs[1,1].hist(x,color='r')
axs[1,0].hist(y,color='cyan')
#giving titles for each subplot

axs[0, 0].set_title("Sorted-scatter of $log(B_{Lc}^{2})$ vs $log(P^{-5}(\dot{P})^{-1}$)",pad=20)
axs[0, 1].set_title("Line plot of $log(B_{Lc}^{2})$ vs $log(P^{-5}(\dot{P})^{-1})$ ",pad=20)
axs[1, 0].set_title("$log(P^{-5}(\dot{P})^{-1})$ ")
axs[1, 1].set_title("$log(B_{Lc}^{2})$")

#since the relation between B_Lc can be given to B_s and it is connected to p & pdot
# Out:
# Text(0.5, 1.0, '$log(B_{Lc}^{2})$')

# %%
import matplotlib 
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
plt.rcParams.update({'font.size': 15})
f = plt.figure()
f.set_figwidth(7)
f.set_figheight(7)
plt.title('$B_{Lc}$ vs $B_{s}$')
plt.xlabel('$B_{Lc}$')
plt.ylabel('$B_{s}$')
plt.scatter(np.sort(np.log(a)),np.sort(np.log(d)),marker='*')
plt.plot(np.sort(np.log(a)),np.sort(np.log(d)))

# %% [markdown]
# ## Tryng for R, using the empirical equation
# ###  $R_{NS} = \frac{\dot{E}^{1/6}}{B_{s}^{1/3}P^{2/3}}$

# %%
R = (((m['Edot'])**(1/6))/((m['B_s'])**(1/3))*((m['po'])**(2/3)))
R
# Out:
# 0    18.386765
# 1    18.334125
# 2    20.379710
# 3    18.411431
# 4    18.423439
# 5    18.403774
# 6    18.377749
# 7    18.468219
# 8    18.397675
# 9    18.328931
# 0    18.390860
# 1    18.340710
# 2    18.389903
# 3    18.357763
# 4    18.390473
# 5    38.319147
# 6    18.340710
# 7    18.373435
# 8    18.348509
# 9    18.382821
# 0    18.295919
# 1    18.384404
# 2    18.378016
# 3    18.368097
# 4    18.380955
# 5    18.390980
# 6    18.395277
# 7    18.398519
# 8    18.382814
# 9    18.363339
# dtype: float64

# %% [markdown]
# ### From I , B, P and Pdot
# ### From relation : $R_{ns} = (\frac{IP\dot{P}}{B_{s}^{2}})^{1/6}$

# %%
R2 = ((m['I']*m['pdot']*m['po'])/(m['B_s']**2))**(1/6)
R2
# Out:
# 0     9.965952
# 1     9.937420
# 2    11.046162
# 3     9.979321
# 4     9.985829
# 5     9.975170
# 6     9.961066
# 7    10.010101
# 8     9.971866
# 9     9.934605
# 0     9.968171
# 1     9.940989
# 2     9.967652
# 3     9.950232
# 4     9.967961
# 5    20.769655
# 6     9.940989
# 7     9.958727
# 8     9.945216
# 9     9.963814
# 0     9.916711
# 1     9.964672
# 2     9.961210
# 3     9.955833
# 4     9.962803
# 5     9.968236
# 6     0.000000
# 7     0.000000
# 8     0.000000
# 9     0.000000
# dtype: float64

# %%
pop=(m['po']*m['pdot'])
pop
# Out:
# 0    1.273274e-14
# 1    1.797968e-22
# 2    3.298568e-22
# 3    1.405727e-14
# 4    1.001414e-15
# 5    1.019553e-13
# 6    9.370110e-15
# 7    1.027193e-13
# 8    1.014355e-22
# 9    4.040577e-15
# 0    8.348786e-16
# 1    2.601187e-15
# 2    3.792960e-15
# 3    2.845348e-15
# 4    2.321089e-12
# 5    2.062149e-15
# 6    2.601187e-15
# 7    6.295540e-15
# 8    3.229315e-15
# 9    2.299493e-14
# 0    1.507834e-10
# 1    2.608845e-17
# 2    2.157227e-10
# 3    4.148200e-09
# 4    1.566977e-11
# 5    4.824050e-10
# 6    4.782478e-10
# 7    3.288748e-12
# 8    6.609115e-11
# 9    5.230550e-10
# dtype: float64

# %%
import pandas as pd
import numpy as np
import math
G={'Name of pulsar':['J0205+6449','J0218+4232','J0437-4715','J0534+2200','J1105-6107','J1124-5916','J1617-5055','J1930+1852','J2124-3358','J2229+6114'],'po':[0.06571592849324,0.00232309053151224,0.005757451936712637,0.0333924123,0.0632021309179,0.13547685441,0.069356847,0.136855046957,0.00493111494309662,0.05162357393],'pdot':[1.93754256e-13,7.73955e-20,5.729215e-20,4.20972e-13,1.584462e-14,7.52566e-13,1.351e-13,7.5057e-13,2.05705e-20,7.827e-14],'D in Kpc':[3.200,3.150,0.157,2.000,2.360, 5.000, 4.743, 7.000, 0.410, 3.000],'Age':[5.37e+03,np.nan,1.59e+09,1.26e+03,6.32e+04,2.85e+03, 8.13e+03, 2.89e+03, np.nan, 1.05e+04],'R_L':[np.nan,466.36,13.52,2200.00,'NaN','NaN','NaN','NaN', 2.86, 13.50],'B_s':[3.61e+12,4.29e+08,4.29e+08,3.79e+12,1.01e+12,1.02e+13,3.1e+12,1.03e+13,3.22e+08,2.03e+12],
'Edot':[2.7e+37,2.4e+35,1.2e+34,4.5e+38,2.5e+36,1.2e+37,1.6e+37,1.2e+37,6.8e+33,2.2e+37],
'Edot2':[2.6e+36,2.5e+34,4.8e+35,1.1e+38,4.4e+35,4.8e+35,7.1e+35,2.4e+35,2.4e+35,2.5e+36],
'B_sI':[3.61e+12,4.27e+08,2.85e+08,3.79e+12,np.nan,np.nan,np.nan,np.nan, 1.92e+08,np.nan],
'B_Lc':[1.19e+05,3.21e+05,2.85e+04,9.55e+05,3.76e+04,3.85e+04, 8.70e+04, 3.75e+04, 2.52e+04, 1.39e+05],
'I':[1.002779e+45,9.857678e+44,1.013579e+45,1.009214e+45,1.010029e+45,1.005339e+45,1.001875e+45,1.039090e+45,1.005033e+45,9.805105e+44]}
l=pd.DataFrame(G)
l.to_csv('High_energy_pulsar.csv')
l
# Out:
#   Name of pulsar        po          pdot  ...          B_sI      B_Lc             I
# 0     J0205+6449  0.065716  1.937543e-13  ...  3.610000e+12  119000.0  1.002779e+45
# 1     J0218+4232  0.002323  7.739550e-20  ...  4.270000e+08  321000.0  9.857678e+44
# 2     J0437-4715  0.005757  5.729215e-20  ...  2.850000e+08   28500.0  1.013579e+45
# 3     J0534+2200  0.033392  4.209720e-13  ...  3.790000e+12  955000.0  1.009214e+45
# 4     J1105-6107  0.063202  1.584462e-14  ...           NaN   37600.0  1.010029e+45
# 5     J1124-5916  0.135477  7.525660e-13  ...           NaN   38500.0  1.005339e+45
# 6     J1617-5055  0.069357  1.351000e-13  ...           NaN   87000.0  1.001875e+45
# 7     J1930+1852  0.136855  7.505700e-13  ...           NaN   37500.0  1.039090e+45
# 8     J2124-3358  0.004931  2.057050e-20  ...  1.920000e+08   25200.0  1.005033e+45
# 9     J2229+6114  0.051624  7.827000e-14  ...           NaN  139000.0  9.805105e+44
#
# [10 rows x 12 columns]

# %%
pop2 = ((m['B_s']**2)*(R**6))/(I)
pop2
# Out:
# 0    1.273274e-14
# 1    1.797968e-22
# 2    3.298568e-22
# 3    1.405727e-14
# 4    1.001414e-15
# 5    1.019553e-13
# 6    9.370110e-15
# 7    1.027193e-13
# 8    1.014355e-22
# 9    4.040577e-15
# 0    8.348786e-16
# 1    2.601187e-15
# 2    3.792960e-15
# 3    2.845348e-15
# 4    2.321089e-12
# 5    2.062149e-15
# 6    2.601187e-15
# 7    6.295540e-15
# 8    3.229315e-15
# 9    2.299493e-14
# 0    1.507834e-10
# 1    2.608845e-17
# 2    2.157227e-10
# 3    4.148200e-09
# 4    1.566977e-11
# 5    4.824050e-10
# 6    4.782478e-10
# 7    3.288748e-12
# 8    6.609115e-11
# 9    5.230550e-10
# dtype: float64

# %%
M = (I/(R2**2))
M
# Out:
# 0    3.981868e+44
# 1    3.936830e+44
# 2    3.276078e+44
# 3    3.996692e+44
# 4    3.994709e+44
# 5    3.984661e+44
# 6    3.982181e+44
# 7    4.089739e+44
# 8    3.986085e+44
# 9    3.918053e+44
# 0    3.990629e+44
# 1    3.934063e+44
# 2    3.983319e+44
# 3    3.972912e+44
# 4    3.994777e+44
# 5    2.481357e+45
# 6    3.934063e+44
# 7    3.975292e+44
# 8    3.957387e+44
# 9    3.976245e+44
# 0    3.906804e+44
# 1    3.960028e+44
# 2    3.976192e+44
# 3    3.963734e+44
# 4    3.999356e+44
# 5    3.989252e+44
# 6             inf
# 7             inf
# 8             inf
# 9             inf
# dtype: float64

# %%
I = ((m['B_s']**(2))*(R**6))/(m['po']*m['pdot'])
I
# Out:
# 0    3.954799e+46
# 1    3.887711e+46
# 2    3.997395e+46
# 3    3.980180e+46
# 4    3.983395e+46
# 5    3.964898e+46
# 6    3.951233e+46
# 7    4.098005e+46
# 8    3.963688e+46
# 9    3.866977e+46
# 0    3.965266e+46
# 1    3.887769e+46
# 2    3.957590e+46
# 3    3.933466e+46
# 4    3.969220e+46
# 5    1.070404e+48
# 6    3.887769e+46
# 7    3.942545e+46
# 8    3.914145e+46
# 9    3.947520e+46
# 0    3.841997e+46
# 1    3.932097e+46
# 2    3.945404e+46
# 3    3.928798e+46
# 4    3.969659e+46
# 5    3.963949e+46
# 6    3.969914e+46
# 7    3.967552e+46
# 8    3.947074e+46
# 9    3.928120e+46
# dtype: float64

# %%
import matplotlib.pyplot as plt
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
plt.rcParams.update({'font.size': 15})
f = plt.figure()
f.set_figwidth(7)
f.set_figheight(7)
plt.scatter(np.sort(R2),np.sort(np.log(M)))

# %%
lum = (R**(2))*((4*np.pi**2)*(2898*10**(-6))**(4))
lum
# Out:
# 0    9.413777e-07
# 1    9.359953e-07
# 2    1.156510e-06
# 3    9.439051e-07
# 4    9.451367e-07
# 5    9.431202e-07
# 6    9.404548e-07
# 7    9.497368e-07
# 8    9.424952e-07
# 9    9.354650e-07
# 0    9.417971e-07
# 1    9.366677e-07
# 2    9.416990e-07
# 3    9.384104e-07
# 4    9.417574e-07
# 5    4.088697e-06
# 6    9.366677e-07
# 7    9.400133e-07
# 8    9.374644e-07
# 9    9.409739e-07
# 0    9.320983e-07
# 1    9.411359e-07
# 2    9.404820e-07
# 3    9.394671e-07
# 4    9.407829e-07
# 5    9.418094e-07
# 6    9.422495e-07
# 7    9.425817e-07
# 8    9.409732e-07
# 9    9.389805e-07
# dtype: float64

# %%
density = M/(R2**3)
density
# Out:
# 0    4.022819e+41
# 1    4.011675e+41
# 2    2.430637e+41
# 3    4.021590e+41
# 4    4.011740e+41
# 5    4.014490e+41
# 6    4.029059e+41
# 7    4.077371e+41
# 8    4.019919e+41
# 9    3.995936e+41
# 0    4.028978e+41
# 1    4.004539e+41
# 2    4.022226e+41
# 3    4.032824e+41
# 4    4.033422e+41
# 5    2.769500e+41
# 6    4.004539e+41
# 7    4.024923e+41
# 8    4.023146e+41
# 9    4.019725e+41
# 0    4.006071e+41
# 1    4.002296e+41
# 2    4.022824e+41
# 3    4.016721e+41
# 4    4.044318e+41
# 5    4.027508e+41
# 6             inf
# 7             inf
# 8             inf
# 9             inf
# dtype: float64

# %%
import matplotlib.pyplot as plt
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
plt.rcParams.update({'font.size': 15})
f = plt.figure()
f.set_figwidth(7)
f.set_figheight(7)
plt.scatter(np.log(lum),m['D in Kpc'])

# %%
ang_mom = m['I']*((2*np.pi)/m['po'])
ang_mom
# Out:
# 0    9.587700e+46
# 1    2.666173e+48
# 2    1.106132e+48
# 3    1.898958e+47
# 4    1.004112e+47
# 5    4.662591e+46
# 6    9.076200e+46
# 7    4.770591e+46
# 8    1.280605e+48
# 9    1.193395e+47
# 0    3.918394e+47
# 1    2.612345e+46
# 2    2.563214e+46
# 3    9.690659e+46
# 4    1.936367e+46
# 5    4.530954e+46
# 6    2.612345e+46
# 7    3.164935e+45
# 8    4.352522e+45
# 9    5.217505e+45
# 0    7.631712e+44
# 1    1.767441e+46
# 2    5.711003e+44
# 3    8.283864e+44
# 4    1.141421e+45
# 5    5.356888e+44
# 6    0.000000e+00
# 7    0.000000e+00
# 8    0.000000e+00
# 9    0.000000e+00
# dtype: float64

# %% [markdown]
# ### also $L_{ang} = \frac{4\pi}{5} \frac{MR^{2}}{P}$

# %% [markdown]
# ### $M = \frac{5PL_{ang}}{4\pi R^{2}}$

# %%
M_ = (5*m['po']*ang_mom)/(4*(np.pi)*(R**2))
M_/(2*10**30)
# Out:
# 0     3.7077e+12
# 1    3.66576e+12
# 2     3.0505e+12
# 3     3.7215e+12
# 4    3.71965e+12
# 5     3.7103e+12
# 6    3.70799e+12
# 7    3.80814e+12
# 8    3.71163e+12
# 9    3.64828e+12
# 0    3.71586e+12
# 1    3.66319e+12
# 2    3.70905e+12
# 3    3.69936e+12
# 4    3.71972e+12
# 5     2.3105e+13
# 6    3.66319e+12
# 7    3.70158e+12
# 8     3.6849e+12
# 9    3.70246e+12
# 0     3.6378e+12
# 1    3.68736e+12
# 2    3.70242e+12
# 3    3.69081e+12
# 4    3.72398e+12
# 5    3.71457e+12
# 6              0
# 7              0
# 8              0
# 9              0
# dtype: object

# %%
lu = (m['I']*m['pdot'])/(m['po'])**3
lu
# Out:
# 0    6.846120e+35
# 1    6.085439e+33
# 2    3.042718e+32
# 3    1.141020e+37
# 4    6.338996e+34
# 5    3.042719e+35
# 6    4.056961e+35
# 7    3.042719e+35
# 8    1.724209e+32
# 9    5.578319e+35
# 0    1.242444e+37
# 1    8.113920e+32
# 2    1.039596e+33
# 3    1.622784e+35
# 4    2.053835e+35
# 5    2.789160e+29
# 6    8.113920e+32
# 7    4.056960e+29
# 8    7.606799e+29
# 9    1.090308e+31
# 0    3.549840e+31
# 1    1.648140e+30
# 2    1.470648e+31
# 3    1.267800e+33
# 4    1.673497e+31
# 5    2.510244e+31
# 6    0.000000e+00
# 7    0.000000e+00
# 8    0.000000e+00
# 9    0.000000e+00
# dtype: float64

# %%
omega = 2*(np.pi)/m['po']
omega
# Out:
# 0      95.611299
# 1    2704.666573
# 2    1091.313549
# 3     188.162067
# 4      99.414137
# 5      46.378293
# 6      90.592142
# 7      45.911243
# 8    1274.191614
# 9     121.711552
# 0     389.722043
# 1      26.500211
# 2      25.543098
# 3      97.162159
# 4      19.239858
# 5       1.669402
# 6      26.500211
# 7       3.165975
# 8       4.385543
# 9       5.212642
# 0       0.783401
# 1      17.727198
# 2       0.570874
# 3       0.831558
# 4       1.133997
# 5       0.532971
# 6       1.208689
# 7       0.900290
# 8       1.669402
# 9       0.780811
# Name: po, dtype: float64

# %% [markdown]
# ### M $\propto R^{3}$
# ### Then the curve shall be like this:

# %%
k = np.arange(0,10**8)
q = np.arange(0,10)

k = q**3
plt.plot(np.log(k),q)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """

# %%
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
plt.rcParams.update({'font.size': 15})
f = plt.figure()
f.set_figwidth(7)
f.set_figheight(7)
plt.scatter(R,R)
plt.plot(R2,R2)
plt.scatter(R2,R2)

# %% [markdown]
# ### This above graph is to check the 2 radius values obtained using different parameters. R is 2 times the R2 values.
#
# ### Although R2 values are most likely to be certain.

# %% [markdown]
# ### Luminosity calculation in terms of $L_{\odot}$

# %%
n=print(lu/(3.826*10**33))

# in solar luminosity L_{sun}
# Out:
# 0     178.936761
# 1       1.590549
# 2       0.079527
# 3    2982.278032
# 4      16.568208
# 5      79.527411
# 6     106.036625
# 7      79.527430
# 8       0.045066
# 9     145.800299
# 0    3247.370981
# 1       0.212073
# 2       0.271719
# 3      42.414636
# 4      53.680998
# 5       0.000073
# 6       0.212073
# 7       0.000106
# 8       0.000199
# 9       0.002850
# 0       0.009278
# 1       0.000431
# 2       0.003844
# 3       0.331364
# 4       0.004374
# 5       0.006561
# 6       0.000000
# 7       0.000000
# 8       0.000000
# 9       0.000000
# dtype: float64

# %% [markdown]
# ### interms of Watts

# %%
# in watts

lu/(3.826*10**26)
# Out:
# 0    1.789368e+09
# 1    1.590549e+07
# 2    7.952740e+05
# 3    2.982278e+10
# 4    1.656821e+08
# 5    7.952741e+08
# 6    1.060366e+09
# 7    7.952743e+08
# 8    4.506557e+05
# 9    1.458003e+09
# 0    3.247371e+10
# 1    2.120732e+06
# 2    2.717186e+06
# 3    4.241464e+08
# 4    5.368100e+08
# 5    7.290015e+02
# 6    2.120732e+06
# 7    1.060366e+03
# 8    1.988186e+03
# 9    2.849733e+04
# 0    9.278201e+04
# 1    4.307736e+03
# 2    3.843828e+04
# 3    3.313643e+06
# 4    4.374011e+04
# 5    6.561014e+04
# 6    0.000000e+00
# 7    0.000000e+00
# 8    0.000000e+00
# 9    0.000000e+00
# dtype: float64

# %% [markdown]
# ### Plot for P and $\ddot{P}$

# %%
p =[0.065715928,0.002323091,0.005757452,0.033392412,0.063202131,0.135476854,0.069356847,0.136855047,0.004931115,0.051623574,0.016122222,0.237099442,0.245983683,0.064667,0.326571288,3.76373308,0.237099442,1.984597367,1.432704197,1.205374441,8.020392,0.354437595,11.0062624,7.55592,5.540742829,11.7889784,5.198346,6.97907097,3.76373308,8.047]
pdot2 = [1.94E-13
,7.74E-20
,5.73E-20
,4.21E-13
,1.58E-14
,7.53E-13
,1.35E-13
,7.51E-13
,2.06E-20
,7.83E-14
,5.18E-14
,1.10E-14
,1.54E-14
,4.40E-14
,7.11E-12
,5.48E-16
,1.10E-14
,3.17E-15
,2.25E-15
,1.91E-14
,1.88E-11
,7.36E-17
,1.96E-11
,5.49E-10
,2.83E-12
,4.09E-11
,9.20E-11
,4.71E-13
,1.76E-11
,6.50E-11]

# %%
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
plt.rcParams.update({'font.size': 15})
f = plt.figure()
f.set_figwidth(7)
f.set_figheight(7)
plt.scatter((np.log(pdot2)),(p)) 
plt.xlabel('$\log{\ddot{P}}$')
plt.ylabel('P')
# Out:
# Text(0, 0.5, 'P')

# %%
pdoubledot = [4.362022e-74,1.435485e-77,1.645689e-78,3.594040e-73,3.765140e-75,3.983752e-74,2.725094e-74,3.599818e-74,8.226702e-79,2.852902e-74,2.014969e-73,1.900034e-76,2.471356e-76,1.021682e-74,6.672220e-74,3.756395e-80,1.915326e-76,7.661261e-79,1.449304e-81,1.315667e-77,2.843571e-76,5.792669e-79,1.571104e-76,9.862808e-75,9.023199e-77,2.863310e-76,3.339180e-75,9.204737e-78,1.206434e-75,9.555010e-76]

# %%
matplotlib.rc('xtick', labelsize=12) 
matplotlib.rc('ytick', labelsize=12) 
plt.rcParams.update({'font.size': 15})
f = plt.figure()
f.set_figwidth(7)
f.set_figheight(7)
plt.scatter(np.sort(np.log(pdoubledot)),np.sort(m['po']))
plt.xlabel('$\log{\ddot{P}}$')
plt.ylabel('P')
# Out:
# Text(0, 0.5, 'P')

# %% [markdown]
# ## All data

# %%
import pandas as pd
import numpy as np
import math
G={'Name of pulsar':['J0205+6449','J0218+4232','J0437-4715','J0534+2200','J1105-6107','J1124-5916','J1617-5055','J1930+1852','J2124-3358','J2229+6114'],'po':[0.06571592849324,0.00232309053151224,0.005757451936712637,0.0333924123,0.0632021309179,0.13547685441,0.069356847,0.136855046957,0.00493111494309662,0.05162357393],'pdot':[1.93754256e-13,7.73955e-20,5.729215e-20,4.20972e-13,1.584462e-14,7.52566e-13,1.351e-13,7.5057e-13,2.05705e-20,7.827e-14],'D in Kpc':[3.200,3.150,0.157,2.000,2.360, 5.000, 4.743, 7.000, 0.410, 3.000],'Age':[5.37e+03,np.nan,1.59e+09,1.26e+03,6.32e+04,2.85e+03, 8.13e+03, 2.89e+03, np.nan, 1.05e+04],'R_L':[np.nan,466.36,13.52,2200.00,'NaN','NaN','NaN','NaN', 2.86, 13.50],'B_s':[3.61e+12,4.29e+08,4.29e+08,3.79e+12,1.01e+12,1.02e+13,3.1e+12,1.03e+13,3.22e+08,2.03e+12],
'Edot':[2.7e+37,2.4e+35,1.2e+34,4.5e+38,2.5e+36,1.2e+37,1.6e+37,1.2e+37,6.8e+33,2.2e+37],
'Edot2':[2.6e+36,2.5e+34,4.8e+35,1.1e+38,4.4e+35,4.8e+35,7.1e+35,2.4e+35,2.4e+35,2.5e+36],
'B_sI':[3.61e+12,4.27e+08,2.85e+08,3.79e+12,np.nan,np.nan,np.nan,np.nan, 1.92e+08,np.nan],
'B_Lc':[1.19e+05,3.21e+05,2.85e+04,9.55e+05,3.76e+04,3.85e+04, 8.70e+04, 3.75e+04, 2.52e+04, 1.39e+05],
'I':[1.002779e+45,9.857678e+44,1.013579e+45,1.009214e+45,1.010029e+45,1.005339e+45,1.001875e+45,1.039090e+45,1.005033e+45,9.805105e+44]}
b=pd.DataFrame(G)

# %%
b
# Out:
#   Name of pulsar        po          pdot  ...          B_sI      B_Lc             I
# 0     J0205+6449  0.065716  1.937543e-13  ...  3.610000e+12  119000.0  1.002779e+45
# 1     J0218+4232  0.002323  7.739550e-20  ...  4.270000e+08  321000.0  9.857678e+44
# 2     J0437-4715  0.005757  5.729215e-20  ...  2.850000e+08   28500.0  1.013579e+45
# 3     J0534+2200  0.033392  4.209720e-13  ...  3.790000e+12  955000.0  1.009214e+45
# 4     J1105-6107  0.063202  1.584462e-14  ...           NaN   37600.0  1.010029e+45
# 5     J1124-5916  0.135477  7.525660e-13  ...           NaN   38500.0  1.005339e+45
# 6     J1617-5055  0.069357  1.351000e-13  ...           NaN   87000.0  1.001875e+45
# 7     J1930+1852  0.136855  7.505700e-13  ...           NaN   37500.0  1.039090e+45
# 8     J2124-3358  0.004931  2.057050e-20  ...  1.920000e+08   25200.0  1.005033e+45
# 9     J2229+6114  0.051624  7.827000e-14  ...           NaN  139000.0  9.805105e+44
#
# [10 rows x 12 columns]

# %%
import pandas as pd
import numpy as np
import math
A={'Name of pulsar':['J0537-6910','J0633+1746','J0543+2329','J1811-1925','J1846-0258','J0628+0909','J0633+1746','J0636-4549','J1811-4930','J1812-1718'],
   'po':[0.0161222220245,0.2370994416923,0.245983683333,0.06466700,0.32657128834,3.763733080,0.2370994416923,1.98459736713,1.4327041968,1.20537444137],
   'pdot':[5.1784338e-14,1.097087e-14,1.541956e-14,4.40e-14,7.107450e-12,0.5479e-15,1.097087e-14,3.1722e-15,2.254e-15,1.9077e-14],
   'D in Kpc':[49.700,0.190,1.565,5.000,5.800,1.771,0.190,0.383,1.447,3.678],
   'R_L':['NaN','NaN',71.03,'NaN','NaN','NaN','NaN','NaN','NaN','NaN'],
   'Age':[4.93e+03,3.42e+05,2.53e+05,2.33e+04,728,3.59e+07,3.42e+05,9.91e+06,1.01e+07,1e+06],
   'B_s':[9.25e+11,1.63e+12,1.97e+12,1.71e+12,4.88e+13,8.35e+11,1.63e+12,2.54e+12,1.82e+12,4.85e+12],
   'Edot':[4.9e+38,3.2e+34,4.1e+34,6.4e+36,8.1e+36,1.1e+31,3.2e+34,1.6e+31,3.0e+31,4.3e+32],
   'Edot2':[2.0e+35,9.0e+35,1.7e+34,2.6e+35,2.4e+35,3.6e+30,9.0e+35,1.1e+32,1.4e+31,3.2e+31],
   'B_sI':['NaN',1.63e+12,1.97e+12,'NaN','NaN','NaN',1.63e+12,'NaN','NaN','NaN'],
   'B_Lc':[2.07e+06,1.15e+03,1.24e+03,5.92e+04,1.31e+04,4.09e+00,1.15e+03,3.05e+00,5.80e+00,2.60e+01,],
           'I':[1.005433e+45,9.857828e+44,1.003486e+45,9.973697e+44,1.006435e+45,2.714117e+46,9.857828e+44,9.996716e+44,9.924706e+44,1.000933e+45]}
c=pd.DataFrame(A)
c
# Out:
#   Name of pulsar        po          pdot  ...      B_sI        B_Lc             I
# 0     J0537-6910  0.016122  5.178434e-14  ...       NaN  2070000.00  1.005433e+45
# 1     J0633+1746  0.237099  1.097087e-14  ...  1.63e+12     1150.00  9.857828e+44
# 2     J0543+2329  0.245984  1.541956e-14  ...  1.97e+12     1240.00  1.003486e+45
# 3     J1811-1925  0.064667  4.400000e-14  ...       NaN    59200.00  9.973697e+44
# 4     J1846-0258  0.326571  7.107450e-12  ...       NaN    13100.00  1.006435e+45
# 5     J0628+0909  3.763733  5.479000e-16  ...       NaN        4.09  2.714117e+46
# 6     J0633+1746  0.237099  1.097087e-14  ...  1.63e+12     1150.00  9.857828e+44
# 7     J0636-4549  1.984597  3.172200e-15  ...       NaN        3.05  9.996716e+44
# 8     J1811-4930  1.432704  2.254000e-15  ...       NaN        5.80  9.924706e+44
# 9     J1812-1718  1.205374  1.907700e-14  ...       NaN       26.00  1.000933e+45
#
# [10 rows x 12 columns]

# %%
import pandas as pd
import numpy as np
import math
R={'Name of pulsar':['J0100-7211','J0525-6607','J1708-4008','J1808-2024','J1809-1943','J1841-0456','J1907+0919','J2301+5852','J1745-2900','J0525-6607'],
   'po':[8.020392, 0.35443759451370,11.0062624,7.55592,5.540742829,11.7889784, 5.198346,6.9790709703,3.763733080,8.0470],
   'pdot':[1.88e-11, 7.36052e-17,1.960e-11,5.49e-10,2.8281e-12,4.092e-11,9.2e-11,4.7123e-13,1.756e-11,6.5e-11],
   'D in Kpc':[59.700, 1.841,3.800,13.000,3.600,9.600,'NaN',3.300,8.300,'NaN'],
   'R_L':['NaN', 66.09,'NaN','NaN','NaN','NaN','NaN','NaN','NaN','NaN'],
   'Age':[6.76e+03,7.63e+07,8.9e+03,218,3.1e+04,4.57e+03,895,2.35e+05,3.4e+03,1.96e+03],
   'B_s':[3.93e+14,1.63e+11,4.7e+14,2.06e+15,1.27e+14,7.03e+14,7e+14,5.8e+13,2.6e+14,7.32e+14],
   'Edot':[1.4e+33,6.5e+31,5.8e+32,5.0e+34,6.6e+32,9.9e+32,2.6e+34,5.5e+31,1.3e+34,4.9e+33],
   'Edot2':[4.0e+29,1.9e+31,4.0e+31,3.0e+32,5.1e+31,1.1e+31,'NaN',5.0e+30,1.9e+32,'NaN'],
   'B_sI':['NaN', 1.62e+11,'NaN',2.06e+15, 1.27e+14,'NaN','NaN', 5.80e+13,2.60e+14,'NaN'],
   'B_Lc':[7.14e+00,3.44e+01,3.30e+00,4.48e+01,6.98e+00,4.02e+00,4.67e+01,1.60e+00,4.57e+01,1.32e+01],
   'I':[9.741766e+44,9.970224e+44,1.000397e+45,9.961860e+44,1.006547e+45,1.005099e+45,0,0,0,0]}
d=pd.DataFrame(R)
d
# Out:
#   Name of pulsar         po          pdot  ...      B_sI   B_Lc             I
# 0     J0100-7211   8.020392  1.880000e-11  ...       NaN   7.14  9.741766e+44
# 1     J0525-6607   0.354438  7.360520e-17  ...  1.62e+11  34.40  9.970224e+44
# 2     J1708-4008  11.006262  1.960000e-11  ...       NaN   3.30  1.000397e+45
# 3     J1808-2024   7.555920  5.490000e-10  ...  2.06e+15  44.80  9.961860e+44
# 4     J1809-1943   5.540743  2.828100e-12  ...  1.27e+14   6.98  1.006547e+45
# 5     J1841-0456  11.788978  4.092000e-11  ...       NaN   4.02  1.005099e+45
# 6     J1907+0919   5.198346  9.200000e-11  ...       NaN  46.70  0.000000e+00
# 7     J2301+5852   6.979071  4.712300e-13  ...   5.8e+13   1.60  0.000000e+00
# 8     J1745-2900   3.763733  1.756000e-11  ...   2.6e+14  45.70  0.000000e+00
# 9     J0525-6607   8.047000  6.500000e-11  ...       NaN  13.20  0.000000e+00
#
# [10 rows x 12 columns]

# %%
m=pd.concat([b,c,d])
m.to_csv('all_included.csv')
m
# Out:
#   Name of pulsar         po          pdot  ...      B_sI        B_Lc             I
# 0     J0205+6449   0.065716  1.937543e-13  ...  3.61e+12   119000.00  1.002779e+45
# 1     J0218+4232   0.002323  7.739550e-20  ...  4.27e+08   321000.00  9.857678e+44
# 2     J0437-4715   0.005757  5.729215e-20  ...  2.85e+08    28500.00  1.013579e+45
# 3     J0534+2200   0.033392  4.209720e-13  ...  3.79e+12   955000.00  1.009214e+45
# 4     J1105-6107   0.063202  1.584462e-14  ...       NaN    37600.00  1.010029e+45
# 5     J1124-5916   0.135477  7.525660e-13  ...       NaN    38500.00  1.005339e+45
# 6     J1617-5055   0.069357  1.351000e-13  ...       NaN    87000.00  1.001875e+45
# 7     J1930+1852   0.136855  7.505700e-13  ...       NaN    37500.00  1.039090e+45
# 8     J2124-3358   0.004931  2.057050e-20  ...  1.92e+08    25200.00  1.005033e+45
# 9     J2229+6114   0.051624  7.827000e-14  ...       NaN   139000.00  9.805105e+44
# 0     J0537-6910   0.016122  5.178434e-14  ...       NaN  2070000.00  1.005433e+45
# 1     J0633+1746   0.237099  1.097087e-14  ...  1.63e+12     1150.00  9.857828e+44
# 2     J0543+2329   0.245984  1.541956e-14  ...  1.97e+12     1240.00  1.003486e+45
# 3     J1811-1925   0.064667  4.400000e-14  ...       NaN    59200.00  9.973697e+44
# 4     J1846-0258   0.326571  7.107450e-12  ...       NaN    13100.00  1.006435e+45
# 5     J0628+0909   3.763733  5.479000e-16  ...       NaN        4.09  2.714117e+46
# 6     J0633+1746   0.237099  1.097087e-14  ...  1.63e+12     1150.00  9.857828e+44
# 7     J0636-4549   1.984597  3.172200e-15  ...       NaN        3.05  9.996716e+44
# 8     J1811-4930   1.432704  2.254000e-15  ...       NaN        5.80  9.924706e+44
# 9     J1812-1718   1.205374  1.907700e-14  ...       NaN       26.00  1.000933e+45
# 0     J0100-7211   8.020392  1.880000e-11  ...       NaN        7.14  9.741766e+44
# 1     J0525-6607   0.354438  7.360520e-17  ...  1.62e+11       34.40  9.970224e+44
# 2     J1708-4008  11.006262  1.960000e-11  ...       NaN        3.30  1.000397e+45
# 3     J1808-2024   7.555920  5.490000e-10  ...  2.06e+15       44.80  9.961860e+44
# 4     J1809-1943   5.540743  2.828100e-12  ...  1.27e+14        6.98  1.006547e+45
# 5     J1841-0456  11.788978  4.092000e-11  ...       NaN        4.02  1.005099e+45
# 6     J1907+0919   5.198346  9.200000e-11  ...       NaN       46.70  0.000000e+00
# 7     J2301+5852   6.979071  4.712300e-13  ...   5.8e+13        1.60  0.000000e+00
# 8     J1745-2900   3.763733  1.756000e-11  ...   2.6e+14       45.70  0.000000e+00
# 9     J0525-6607   8.047000  6.500000e-11  ...       NaN       13.20  0.000000e+00
#
# [30 rows x 12 columns]
